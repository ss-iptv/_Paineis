# %% [markdown]
# ##### ***BAIXAR OS SCRIPTS***

# %%
# PRIMEIRO AQUI O SCRIPT PARA BAIXAR OS SCRIPTS

# !pip install -q colorama
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/
# !git clone https://github.com/ss-iptv/_Paineis.git
# %cd /content/drive/MyDrive/_Paineis
# !git pull
#!git fetch --all

# %%
# PRIMEIRO AQUI O SCRIPT PARA BAIXAR OS SCRIPTS

# !pip install -q colorama
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_teste
# !git clone https://github.com/ss-iptv/_Paineis.git
# %cd /content/drive/MyDrive/_Paineis
# !git pull
#!git fetch --all

# %% [markdown]
# ##### ***GERAR O USER PASS***

# %%
#GERA USER E PASS ELABORADO
from google.colab import drive
drive.mount('/content/drive')
import random
import string

def gerar_senha_com_ano(nome, ano):
    """Gera uma senha com base no nome e no ano, adicionando caracteres aleatórios."""
    senha_base = f"{nome.lower()}{ano}"
    caracteres_especiais = string.punctuation
    caracteres_aleatorios = ''.join(random.choice(string.ascii_letters + string.digits + caracteres_especiais) for _ in range(3))
    return senha_base + caracteres_aleatorios

def gerar_usuario_senha(num_usuarios=500000):
    usuarios_senhas = []
    for nome in nomes:
        for numero in range(100):
            usuario = f"{nome}{numero:02d}"
            # Opções de senha com diferentes anos
            senhas = [
                gerar_senha_com_ano(nome, 2022),
                gerar_senha_com_ano(nome, 2023),
                gerar_senha_com_ano(nome, 2024),
            ]
            for senha in senhas:
                usuarios_senhas.append(f"{usuario}:{senha}")
    return usuarios_senhas
nomes = [

    # Portuguese Names (1250 names)
    "Adriano", "Albertina", "Alessandro", "Alexandra", "Alfredo", "Alice", "Marlon", "Amanda", "Antonio", "Armando", "Augusto",
    "Beatriz", "Benedito", "Benjamin", "Bernardo", "Bianca", "Bruna", "Bruno", "Camila", "Carlos", "Carolina",
    "Catarina", "Cecilia", "Clarice", "Claudia", "Cristiano", "Daniel", "Daniela", "Debora", "Diana", "Diego",
    "Eduardo", "Elaine", "Eliana", "Elisa", "Elizabeth", "Emilia", "Emilio", "Fabiana", "Fabiano", "Fabio", "Felipe",
    "Fernanda", "Fernando", "Filipe", "Flavia", "Francisco", "Gabriel", "Gabriela", "Giovanna", "Giovanni", "Guilherme",
    "Gustavo", "Helena", "Henrique", "Igor", "Isabel", "Isabella", "Isabelle", "Isadora", "Janaina", "Joana",
    "Joaquim", "Jorge", "Jose", "Josiane", "Julia", "Juliana", "Juliano", "Karen", "Karina", "Larissa",
    "Laura", "Leandro", "Leonardo", "Leticia", "Livia", "Lorenzo", "Lucas", "Luciana", "Luciano", "Luiza",
    "Manuela", "Marcela", "Marcelo", "Marcia", "Marco", "Marcos", "Maria", "Mariana", "Marina", "Mario",
    "Matheus", "Mauricio", "Michele", "Miguel", "Natalia", "Nicolas", "Nicole", "Otavio", "Patricia", "Paulo",
    "Pedro", "Rafael", "Rafaela", "Raquel", "Renata", "Ricardo", "Roberto", "Rodrigo", "Ronaldo", "Samuel",
    "Sandra", "Santiago", "Sarah", "Sergio", "Silvana", "Silvia", "Simone", "Sofia", "Stefano", "Talita",
    "Tatiana", "Thiago", "Valentina", "Valeria", "Vanessa", "Vicente", "Victor", "Victoria", "Vinicius", "Vitoria",
    "Wagner", "William", "Yago", "Yasmin",

    # Spanish Names (1250 names)
    "Adriana", "Agustin", "Alberto", "Alejandra", "Alejandro", "Alfonso", "Alvaro", "Lana", "Andrea", "Andres",
    "Angela", "Antonio", "Ariadna", "Arturo", "Barbara", "Beatriz", "Belen", "Benito", "Blanca", "Camilo",
    "Carla", "Carlos", "Carmen", "Carolina", "Catalina", "Cesar", "Clara", "Claudia", "Cristian", "Cristina",
    "Daniel", "David", "Diana", "Diego", "Eduardo", "Elena", "Elisa", "Emilio", "Enrique", "Esteban",
    "Esther", "Eva", "Federico", "Felipe", "Fernanda", "Fernando", "Francisco", "Gabriel", "Gabriela", "German",
    "Gloria", "Gonzalo", "Graciela", "Guadalupe", "Guillermo", "Gustavo", "Hector", "Hugo", "Ignacio", "Ines",
    "Irene", "Isabel", "Isabela", "Jaime", "Javier", "Jesus", "Jorge", "Jose", "Juan", "Juana",
    "Julia", "Julian", "Laura", "Leonardo", "Lucia", "Luis", "Luna", "Manuel", "Marcela", "Marcos",
    "Margarita", "Maria", "Mariana", "Mario", "Martin", "Mateo", "Mercedes", "Miguel", "Monica", "Natalia",
    "Nicolas", "Oscar", "Pablo", "Patricia", "Paula", "Pedro", "Pilar", "Rafael", "Ramiro", "Raquel",
    "Ricardo", "Roberto", "Rocio", "Rodrigo", "Rosa", "Rosario", "Salvador", "Santiago", "Sara", "Sebastian",
    "Sergio", "Silvia", "Sofia", "Susana", "Teresa", "Tomas", "Valeria", "Veronica", "Vicente", "Victor",
    "Victoria", "Virginia", "Ximena", "Yolanda",

    # Italian Names (1250 names)
    "Adriano", "Agnese", "Alberto", "Alessandra", "Alessandro", "Alessia", "Alice", "Andrea", "Angelo", "Anna",
    "Annalisa", "Antonella", "Antonio", "Arturo", "Barbara", "Beatrice", "Benedetta", "Bianca", "Bruno", "Carla",
    "Carlo", "Carmela", "Carolina", "Caterina", "Cecilia", "Chiara", "Christian", "Clara", "Claudia", "Claudio",
    "Cristian", "Cristina", "Damiano", "Daniela", "Daniele", "Davide", "Diego", "Elena", "Eleonora", "Elisa",
    "Elisabetta", "Emanuele", "Emilia", "Enrico", "Enzo", "Fabio", "Fabrizio", "Federico", "Federica", "Filippo",
    "Francesca", "Francesco", "Gabriele", "Gabriella", "Giacomo", "Giada", "Giancarlo", "Gianfranco", "Gianluca", "Gianmarco",
    "Gianni", "Giorgio", "Giovanna", "Giovanni", "Giulia", "Giuliana", "Giulio", "Giuseppe", "Grazia", "Guido",
    "Isabella", "Laura", "Leonardo", "Lorenzo", "Luca", "Lucia", "Luciano", "Luigi", "Manuel", "Marco",
    "Margherita", "Maria", "Marina", "Mario", "Marta", "Martina", "Massimo", "Matteo", "Mattia", "Maurizio",
    "Michele", "Monica", "Nicola", "Nicoletta", "Orietta", "Paola", "Paolo", "Patrizia", "Pietro", "Raffaele",
    "Riccardo", "Roberto", "Romano", "Rosa", "Rosaria", "Salvatore", "Sandra", "Sebastiano", "Serena", "Sergio",
    "Silvana", "Silvia", "Simona", "Simone", "Stefania", "Stefano", "Teresa", "Tiziana", "Tommaso", "Umberto",
    "Valentina", "Valeria", "Valerio", "Veronica", "Vincenzo", "Vittoria", "Vittorio",

    # French Names (1250 names)
    "Adeline", "Adrian", "Agnes", "Alain", "Albert", "Alexandre", "Alice", "Aline", "Andre", "Angelique",
    "Annie", "Antoine", "Arnaud", "Audrey", "Aurelie", "Baptiste", "Beatrice", "Benjamin", "Benoit", "Bernard",
    "Bertrand", "Brigitte", "Bruno", "Caroline", "Catherine", "Cecile", "Cedric", "Chantal", "Charles", "Charlotte",
    "Christian", "Christine", "Christophe", "Claire", "Claude", "Clemence", "Colette", "Corinne", "Daniel", "Danielle",
    "David", "Delphine", "Denis", "Denise", "Didier", "Dominique", "Edith", "Edmond", "Edouard", "Elisabeth",
    "Emilie", "Emmanuel", "Eric", "Etienne", "Eugene", "Fabien", "Fabrice", "Felix", "Florence", "Francis",
    "Francois", "Francoise", "Frederick", "Gabriel", "Gabrielle", "Georges", "Gerard", "Germain", "Gilbert", "Gilles",
    "Guillaume", "Guy", "Helene", "Henri", "Henriette", "Herve", "Hubert", "Hugues", "Isabelle", "Jacques",
    "Jean", "Jeanne", "Jerome", "Joel", "Joseph", "Josephine", "Jules", "Julien", "Juliette", "Laurent",
    "Leon", "Louis", "Louise", "Luc", "Lucas", "Lucien", "Madeleine", "Marcel", "Marguerite", "Marie",
    "Mariette", "Marion", "Martin", "Martine", "Mathieu", "Maurice", "Michel", "Michele", "Monique", "Nathalie",
    "Nicolas", "Nicole", "Olivier", "Pascal", "Patrice", "Patricia", "Paul", "Philippe", "Pierre", "Rachel",
    "Raymond", "Remy", "Renaud", "Rene", "Richard", "Robert", "Roger", "Roland", "Sebastien", "Simone",
    "Sophie", "Stephane", "Suzanne", "Sylvain", "Sylvie", "Therese", "Thierry", "Thomas", "Valentine", "Valerie",
    "Vincent", "Virginie", "Xavier", "Yves", "Yvette", "Elton",

    "Alice", "Bob", "Carlos", "Diana", "Eva", "Joao", "Maria", "Pedro", "Ana", "Lucas", "Carla", "Rafael", "Fernanda", "Gabriel", "Juliana", "Bruno", "Larissa", "Felipe", "Camila", "Thiago", "Patricia", "Gustavo", "Renata", "Rodrigo", "Aline", "Daniel", "Beatriz", "Vinicius", "Mariana", "Leonardo", "Isabela", "Ricardo", "Tatiana", "Eduardo", "Vanessa", "Marcelo", "Leticia", "Andre", "Carolina", "Diego", "Natalia", "Fernando", "Bianca", "Alexandre", "Gabriela", "Rogerio", "Paula", "Murilo", "Sabrina", "Fabio", "Elaine", "Paulo", "Marcos", "Luisa", "Amanda", "Arthur", "Renato", "Raquel", "Carlos", "Bruna", "Alessandra", "Adriana", "Claudia", "Matheus", "Marta", "Julio", "Roberto", "Rita", "Edson", "Luciana", "Debora", "Gilberto", "Silvana", "Nelson", "Cecilia", "Tadeu", "Marlene", "Sonia", "Cassio", "Angela", "Josue", "Heloisa", "Paloma", "Ruan", "Vitor", "Lucio", "Mirela", "Flavio", "Simone", "Elias", "Katia", "Francisco", "Lorena", "Mario", "Otavio", "Evelyn", "Tiago", "Selma", "Vera
de", "Apparition", "Adalia", "Anselme", "Valdemar", "Natalino", "Cleber", "Leonel", "Belmiro", "Raulino", "Aida", "Rildo", "Quiteria", "Daiana", "Gervais", "Odaleia", "Euclide", "Jacira", "Donizete", "Judith", "Celio", "Amelie", "Joel", "Isaura", "Itamar", "Arminda", "Altamir", "Rosangela", "Durval", "Lourdes", "Iolanda", "Adonias", "Isaurina", "Osmar", "Suzanne", "Palmira", "Bernadette", "Leopold", "Eunice", "Rubem", "Jerome", "Marilia", "Mathias", "Malvina", "Pascal", "Marguerite", "Eduarda", "Lisandra", "Eron", "Othoniel", "Marcel", "Benigne", "Remi", "Leonore", "Theophile", "Jaci", "Eladio", "Lavinia", "Remi", "Perpetue", "Olympio", "Fabrice", "Fabiola", "Nonato", "Sineia", "Antenor", "Victoire", "Zachee", "Mathilde", "Ernani", "Julinho", "Lucilia", "Altamiro", "Apparition", "Georgina", "Adelino", "Emanuela", "Cassiano", "Benedicte", "Anabela", "Ambroise", "Therese", "Naide", "Benicio", "Aurelia", "Inacia", "Dorothee", "Adalgisa", "Donato", "Romildo", "Ernesta", "Cecile", "Tarcila", "Emile", "Gerda", "Aretusa", "Alberico", "Rosalinda", "Delfino", "Onilda", "Adson", "Anisio", "Waldemir", "Iranete", "Agripina", "Efigenia", "Jarbas", "Anita", "Mariano", "Dolores", "Higino", "Estevina", "Octavien", "Idilio", "Juliette", "Tibere", "Gessilda", "Venilda", "Germano", "Hortense", "Aristeu", "Aguinalda", "Nelio", "Lenilson", "Zeli", "Giovani", "Nicodeme", "Lismara", "Antao", "Alzira", "Loamir", "Jussara", "Ivan", "Marly", "Giliard", "Dirceu", "Bertha", "Giovanni", "Leonilda", "Ilario", "Gracinha", "Romualdo", "Estefania", "Ernesto", "Gislene", "Osorio", "Gioconda", "Omar", "Filomena", "Isa", "Felicio", "Eustaquia", "Guida", "Estevao", "Joselia", "Zeferino", "Lindalva", "Carmelita", "Piedade", "Tecla", "Baltazar", "Leontina", "Leda", "Getulio", "Sigismundo", "Olinda", "Telmo", "Adelina", "Ariane", "Armando", "Augusto", "Benedito", "Bernardo", "Caio", "Catarina", "Dalva", "Denise"]  # Exemplo de lista de nomes

import random

def gerar_usuario_senha(num_usuarios=5000):
    usuarios_senhas = []

    for _ in range(num_usuarios):
        numero = random.randint(0, 99)
        nome = random.choice(nomes)  # Escolhe um nome aleatório da lista
        usuario = f"{nome}{numero:02d}"  # Cria o nome de usuário com o número
        senha1 = f"{numero:02d}{nome.capitalize()}"  # Cria a primeira senha formatada
        senha2 = f"{nome}{numero:02d}"  # Outra senha formatada
        senha3 = "102030"  # Senha fixa
        senha4 = "10203040"  # Senha fixa
        senha5 = "112233"  # Senha fixa
        senha6 = f"{nome.lower()}{numero:02d}"  # Senha formatada em minúsculas
        senha7 = f"{nome}123"  # Nova senha: nome seguido de 123
        senha8 = "123456789"  # Senha fixa
        senha9 = f"{numero:02d}{nome.lower()}"  # Senha NUM.NOM formatada em minúsculas
        # Adicionando opções de senha com os anos 2022, 2023 e 2024
        senha10 = f"{nome}2022"
        senha11 = f"{nome}2023"
        senha12 = f"{nome}2024"
        senha13 = f"{nome.lower()}"  # Cria a primeira senha formatada

        usuarios_senhas.extend([
            f"{usuario}:{senha1}",
            f"{usuario}:{senha2}",
            f"{usuario}:{senha3}",
            f"{usuario}:{senha4}",
            f"{usuario}:{senha5}",
            f"{usuario}:{senha6}",
            f"{usuario}:{senha7}",
            f"{usuario}:{senha8}",
            f"{usuario}:{senha9}",
            f"{usuario}:{senha10}",
            f"{usuario}:{senha11}",
            f"{usuario}:{senha12}",
            f"{usuario}:{senha13}",

        ])

    return usuarios_senhas

# Gerar 100000 usuários e senhas e salvar em um arquivo de texto no Google Drive
caminho_arquivo = '/content/drive/MyDrive/_Paineis/combo/usuarios_senhas.txt'
caminho_arquivo = '/content/drive/MyDrive/_Paineis/data/credentials.txt'
with open(caminho_arquivo, 'w') as file:
    # Gerar usuários e senhas
    usuarios_senhas = gerar_usuario_senha(5000)  # Gera os primeiros 2000
    file.write('\n'.join(usuarios_senhas) + '\n')

    usuarios_senhas = gerar_usuario_senha(5000)  # Gera os próximos 2000
    file.write('\n'.join(usuarios_senhas) + '\n')

print(f"Arquivo salvo em {caminho_arquivo}")

# %% [markdown]
# ##### ***GERAR O ADMIN PASS***

# %%
# !pip install -q faker
import random
from faker import Faker

# Especificar o caminho do arquivo e a quantidade de linhas desejada
caminho_arquivo = 'usuarios_senhas.txt'
num_senhas = 5000  # Quantidade de senhas desejada

# Criar instâncias do Faker para pt_PT e pt_BR
faker_pt = Faker('pt_PT')
faker_br = Faker('pt_BR')

def gerar_senha_com_ano(nome, ano, maiuscula=True):
    """Gera uma senha com base no nome e no ano, com a opção de iniciar com letra maiúscula ou minúscula."""
    if maiuscula:
        return f"{nome.capitalize()}{ano}"
    else:
        return f"{nome.lower()}{ano}"

def gerar_senhas_admin(num_senhas=5000):
    usuarios_senhas = []
    nome = "admin"
    for _ in range(num_senhas):
        anos = [2022, 2023, 2024]
        for ano in anos:
            senha_maiuscula = gerar_senha_com_ano(nome, ano, maiuscula=True)
            senha_minuscula = gerar_senha_com_ano(nome, ano, maiuscula=False)
            usuarios_senhas.append(f"{nome}:{senha_minuscula}")
            usuarios_senhas.append(f"{nome}:{senha_maiuscula}")
        senhas = [
            "102030",
            "10203040",
            "112233",
            f"{nome.capitalize()}123",
            "123456789",
            f"{nome.capitalize()}"
        ]
        for senha in senhas:
            usuarios_senhas.append(f"{nome}:{senha}")
    return usuarios_senhas[:num_senhas]

# Função para gerar e salvar usuários e senhas em um arquivo
def salvar_usuarios_senhas(caminho_arquivo, num_senhas):
    with open(caminho_arquivo, 'w') as file:
        usuarios_senhas = gerar_senhas_admin(num_senhas)
        file.write('\n'.join(usuarios_senhas) + '\n')
    print(f"Arquivo salvo em {caminho_arquivo}")

# Salvar os usuários e senhas no arquivo especificado
salvar_usuarios_senhas(caminho_arquivo, num_senhas)

# %% [markdown]
# ##### ***AutoPanelLogin!***

# %%
#PAINEL ONE - WOLF - STONE - BRTV - INOVA

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()
# !pip install -q colorama
# !python Multi_Uni_Npanel.py

# %% [markdown]
# ##### PAINEIS SEPARADOS

# %%
# RODA INOVA E STONE

import subprocess
import threading
import time
from IPython.display import clear_output

def run_command(command):
  """Runs a command in a subprocess and prints its output."""
  process = subprocess.Popen(command, shell=True, stdout=subprocess.PIPE, stderr=subprocess.PIPE, text=True)
  while True:
    output = process.stdout.readline()
    if output == '' and process.poll() is not None:
      break
    if output:
      print(output.strip())
  rc = process.poll()
  return rc


def run_python_script(script_path):
  """Runs a python script in a separate thread."""
  def thread_func():
    command = f'python {script_path}'
    run_command(command)
  thread = threading.Thread(target=thread_func)
  thread.start()
  return thread


# Define the paths to your Python scripts
script1_path = '/content/drive/MyDrive/_Paineis/hell/Sr.Hell_inova_tv.py'
script2_path = '/content/drive/MyDrive/_Paineis/hell/_Sr.Hell_One_tv.py'


thread1 = run_python_script(script1_path)
thread2 = run_python_script(script2_path)


# Keep the Colab notebook running while the scripts are executing
while True:
  time.sleep(1)
  clear_output(wait=True)

# %%
#PAINEL HIGH

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python Sr.Hell_high_tv.py

# %%
#PAINEL STAR

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python Sr.Hell_Star_tv.py

# %%
#PAINEL ONE

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python _Sr.Hell_One_tv.py

# %%
#PAINEL INOVA

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python Sr.Hell_inova_tv.py

# %%
#PAINEL BRTV

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python Sr.Hell_BRTV_tv.py

# %%
#PAINEL AZBRTV

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()
# !git pull
# !pip install cloudscraper
# !pip install requests[socks]
# !pip install  stem
# !python Sr.Hell_az_cf_tv.py

# %%
#PAINEL BRTV

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python Sr.Hell_WOLF_tv.py

# %%
#PAINEL p2ponline

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python Sr.Hell_p2ponline_tv.py

# %%
#PAINEL BRTV

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/hell

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python Sr.Hell_PremiumCardTv_tv.py

# %% [markdown]
# ##### ***CLARO TV+ TVEXPRESS***

# %%
# CLARO TV+

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python ClaroTv-base.py

# %%
#TVEXPRESS + EPPI + MFC + REDPLAY

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis/

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()

# !python TvExpreess.py

# %% [markdown]
# ##### ***GERAR 500000 FAKER - USER PASS***

# %%
#GERADOR DE USER E PASS - USANDO O FAKER
# !pip install -q faker
import random
import string
from faker import Faker
from google.colab import drive
# Montar o Google Drive
drive.mount('/content/drive')

# Especificar o caminho do arquivo e a quantidade de linhas desejada
caminho_arquivo = '/content/drive/MyDrive/_Paineis/combo/usuarios_senhas.txt'
num_linhas = 500000  # Altere este valor para a quantidade de linhas desejada

# Criar instâncias do Faker para pt_PT e pt_BR
faker_pt = Faker('pt_PT')
faker_br = Faker('pt_BR')

def gerar_senha_com_ano(nome, ano, maiuscula=True):
    """Gera uma senha com base no nome e no ano, com a opção de iniciar com letra maiúscula ou minúscula."""
    if maiuscula:
        return f"{nome.capitalize()}{ano}"
    else:
        return f"{nome.lower()}{ano}"

def gerar_usuario_senha(num_usuarios=5000):
    usuarios_senhas = []
    for _ in range(num_usuarios):
        # Alternar entre nomes pt_PT e pt_BR e garantir que tenham pelo menos 6 caracteres
        while True:
            nome = random.choice([faker_pt.first_name(), faker_br.first_name()])
            if len(nome.split()[0]) >= 6:  # Usar apenas o primeiro nome e garantir que tenha pelo menos 6 caracteres
                nome = nome.split()[0]
                break
        numero = random.randint(0, 99)
        usuario = f"{nome}{numero:02d}"
        anos = [2022, 2023, 2024]
        for ano in anos:
            senha_maiuscula = gerar_senha_com_ano(nome, ano, maiuscula=True)
            senha_minuscula = gerar_senha_com_ano(nome, ano, maiuscula=False)
            usuario_ano = f"{nome}{ano}"
            usuarios_senhas.append(f"{usuario_ano}:{senha_minuscula}")
            usuarios_senhas.append(f"{usuario_ano}:{senha_maiuscula}")
        senhas = [
            f"{numero:02d}{nome.capitalize()}",
            f"{nome.capitalize()}{numero:02d}",
            "102030",
            "10203040",
            "112233",
            f"{nome.capitalize()}{numero:02d}",
            f"{nome.capitalize()}123",
            "123456789",
            f"{numero:02d}{nome.capitalize()}",
            f"{nome.capitalize()}"
        ]
        for senha in senhas:
            usuarios_senhas.append(f"{usuario}:{senha}")
    return usuarios_senhas

# Função para gerar e salvar usuários e senhas em um arquivo no Google Drive
def salvar_usuarios_senhas(caminho_arquivo, num_linhas):
    with open(caminho_arquivo, 'w') as file:
        usuarios_senhas = gerar_usuario_senha(num_linhas)
        file.write('\n'.join(usuarios_senhas) + '\n')
    print(f"Arquivo salvo em {caminho_arquivo}")

# Salvar os usuários e senhas no arquivo especificado
salvar_usuarios_senhas(caminho_arquivo, num_linhas)

# %% [markdown]
# ##### ***NOVO AutoPanelLogin!***

# %%
#PAINEL ONE - WOLF - STONE - BRTV - INOVA

import time
import threading
from IPython.display import clear_output
from google.colab import drive
drive.mount('/content/drive')
# %cd /content/drive/MyDrive/_Paineis

def clear_output_periodically(interval_seconds):
  while True:
    clear_output(wait=True)
    time.sleep(interval_seconds)

# Example usage: clear output every 5 seconds
t = threading.Thread(target=clear_output_periodically, args=(5,))
t.start()
# !pip install -q colorama
# !python main.py

# %% [markdown]
# ##### ***GERAR O USER PASS SIMPLES***

# %%
#GERA USER E PASS ELABORADO
from google.colab import drive
drive.mount('/content/drive')
import random
import string

def gerar_senha_com_ano(nome, ano):
    """Gera uma senha com base no nome e no ano, adicionando caracteres aleatórios."""
    senha_base = f"{nome.lower()}{ano}"
    caracteres_especiais = string.punctuation
    caracteres_aleatorios = ''.join(random.choice(string.ascii_letters + string.digits + caracteres_especiais) for _ in range(3))
    return senha_base + caracteres_aleatorios

def gerar_usuario_senha(num_usuarios=500000):
    usuarios_senhas = []
    for nome in nomes:
        for numero in range(100):
            usuario = f"{nome}{numero:02d}"
            # Opções de senha com diferentes anos
            senhas = [
                gerar_senha_com_ano(nome, 2022),
                gerar_senha_com_ano(nome, 2023),
                gerar_senha_com_ano(nome, 2024),
            ]
            for senha in senhas:
                usuarios_senhas.append(f"{usuario}:{senha}")
    return usuarios_senhas
nomes = [

    # Portuguese Names (1250 names)
    "Adriano", "Albertina", "Alessandro", "Alexandra", "Alfredo", "Alice", "Marlon", "Amanda", "Antonio", "Armando", "Augusto",
    "Beatriz", "Benedito", "Benjamin", "Bernardo", "Bianca", "Bruna", "Bruno", "Camila", "Carlos", "Carolina",
    "Catarina", "Cecilia", "Clarice", "Claudia", "Cristiano", "Daniel", "Daniela", "Debora", "Diana", "Diego",
    "Eduardo", "Elaine", "Eliana", "Elisa", "Elizabeth", "Emilia", "Emilio", "Fabiana", "Fabiano", "Fabio", "Felipe",
    "Fernanda", "Fernando", "Filipe", "Flavia", "Francisco", "Gabriel", "Gabriela", "Giovanna", "Giovanni", "Guilherme",
    "Gustavo", "Helena", "Henrique", "Igor", "Isabel", "Isabella", "Isabelle", "Isadora", "Janaina", "Joana",
    "Joaquim", "Jorge", "Jose", "Josiane", "Julia", "Juliana", "Juliano", "Karen", "Karina", "Larissa",
    "Laura", "Leandro", "Leonardo", "Leticia", "Livia", "Lorenzo", "Lucas", "Luciana", "Luciano", "Luiza",
    "Manuela", "Marcela", "Marcelo", "Marcia", "Marco", "Marcos", "Maria", "Mariana", "Marina", "Mario",
    "Matheus", "Mauricio", "Michele", "Miguel", "Natalia", "Nicolas", "Nicole", "Otavio", "Patricia", "Paulo",
    "Pedro", "Rafael", "Rafaela", "Raquel", "Renata", "Ricardo", "Roberto", "Rodrigo", "Ronaldo", "Samuel",
    "Sandra", "Santiago", "Sarah", "Sergio", "Silvana", "Silvia", "Simone", "Sofia", "Stefano", "Talita",
    "Tatiana", "Thiago", "Valentina", "Valeria", "Vanessa", "Vicente", "Victor", "Victoria", "Vinicius", "Vitoria",
    "Wagner", "William", "Yago", "Yasmin",

    # Spanish Names (1250 names)
    "Adriana", "Agustin", "Alberto", "Alejandra", "Alejandro", "Alfonso", "Alvaro", "Lana", "Andrea", "Andres",
    "Angela", "Antonio", "Ariadna", "Arturo", "Barbara", "Beatriz", "Belen", "Benito", "Blanca", "Camilo",
    "Carla", "Carlos", "Carmen", "Carolina", "Catalina", "Cesar", "Clara", "Claudia", "Cristian", "Cristina",
    "Daniel", "David", "Diana", "Diego", "Eduardo", "Elena", "Elisa", "Emilio", "Enrique", "Esteban",
    "Esther", "Eva", "Federico", "Felipe", "Fernanda", "Fernando", "Francisco", "Gabriel", "Gabriela", "German",
    "Gloria", "Gonzalo", "Graciela", "Guadalupe", "Guillermo", "Gustavo", "Hector", "Hugo", "Ignacio", "Ines",
    "Irene", "Isabel", "Isabela", "Jaime", "Javier", "Jesus", "Jorge", "Jose", "Juan", "Juana",
    "Julia", "Julian", "Laura", "Leonardo", "Lucia", "Luis", "Luna", "Manuel", "Marcela", "Marcos",
    "Margarita", "Maria", "Mariana", "Mario", "Martin", "Mateo", "Mercedes", "Miguel", "Monica", "Natalia",
    "Nicolas", "Oscar", "Pablo", "Patricia", "Paula", "Pedro", "Pilar", "Rafael", "Ramiro", "Raquel",
    "Ricardo", "Roberto", "Rocio", "Rodrigo", "Rosa", "Rosario", "Salvador", "Santiago", "Sara", "Sebastian",
    "Sergio", "Silvia", "Sofia", "Susana", "Teresa", "Tomas", "Valeria", "Veronica", "Vicente", "Victor",
    "Victoria", "Virginia", "Ximena", "Yolanda",

    # Italian Names (1250 names)
    "Adriano", "Agnese", "Alberto", "Alessandra", "Alessandro", "Alessia", "Alice", "Andrea", "Angelo", "Anna",
    "Annalisa", "Antonella", "Antonio", "Arturo", "Barbara", "Beatrice", "Benedetta", "Bianca", "Bruno", "Carla",
    "Carlo", "Carmela", "Carolina", "Caterina", "Cecilia", "Chiara", "Christian", "Clara", "Claudia", "Claudio",
    "Cristian", "Cristina", "Damiano", "Daniela", "Daniele", "Davide", "Diego", "Elena", "Eleonora", "Elisa",
    "Elisabetta", "Emanuele", "Emilia", "Enrico", "Enzo", "Fabio", "Fabrizio", "Federico", "Federica", "Filippo",
    "Francesca", "Francesco", "Gabriele", "Gabriella", "Giacomo", "Giada", "Giancarlo", "Gianfranco", "Gianluca", "Gianmarco",
    "Gianni", "Giorgio", "Giovanna", "Giovanni", "Giulia", "Giuliana", "Giulio", "Giuseppe", "Grazia", "Guido",
    "Isabella", "Laura", "Leonardo", "Lorenzo", "Luca", "Lucia", "Luciano", "Luigi", "Manuel", "Marco",
    "Margherita", "Maria", "Marina", "Mario", "Marta", "Martina", "Massimo", "Matteo", "Mattia", "Maurizio",
    "Michele", "Monica", "Nicola", "Nicoletta", "Orietta", "Paola", "Paolo", "Patrizia", "Pietro", "Raffaele",
    "Riccardo", "Roberto", "Romano", "Rosa", "Rosaria", "Salvatore", "Sandra", "Sebastiano", "Serena", "Sergio",
    "Silvana", "Silvia", "Simona", "Simone", "Stefania", "Stefano", "Teresa", "Tiziana", "Tommaso", "Umberto",
    "Valentina", "Valeria", "Valerio", "Veronica", "Vincenzo", "Vittoria", "Vittorio",

    # French Names (1250 names)
    "Adeline", "Adrian", "Agnes", "Alain", "Albert", "Alexandre", "Alice", "Aline", "Andre", "Angelique",
    "Annie", "Antoine", "Arnaud", "Audrey", "Aurelie", "Baptiste", "Beatrice", "Benjamin", "Benoit", "Bernard",
    "Bertrand", "Brigitte", "Bruno", "Caroline", "Catherine", "Cecile", "Cedric", "Chantal", "Charles", "Charlotte",
    "Christian", "Christine", "Christophe", "Claire", "Claude", "Clemence", "Colette", "Corinne", "Daniel", "Danielle",
    "David", "Delphine", "Denis", "Denise", "Didier", "Dominique", "Edith", "Edmond", "Edouard", "Elisabeth",
    "Emilie", "Emmanuel", "Eric", "Etienne", "Eugene", "Fabien", "Fabrice", "Felix", "Florence", "Francis",
    "Francois", "Francoise", "Frederick", "Gabriel", "Gabrielle", "Georges", "Gerard", "Germain", "Gilbert", "Gilles",
    "Guillaume", "Guy", "Helene", "Henri", "Henriette", "Herve", "Hubert", "Hugues", "Isabelle", "Jacques",
    "Jean", "Jeanne", "Jerome", "Joel", "Joseph", "Josephine", "Jules", "Julien", "Juliette", "Laurent",
    "Leon", "Louis", "Louise", "Luc", "Lucas", "Lucien", "Madeleine", "Marcel", "Marguerite", "Marie",
    "Mariette", "Marion", "Martin", "Martine", "Mathieu", "Maurice", "Michel", "Michele", "Monique", "Nathalie",
    "Nicolas", "Nicole", "Olivier", "Pascal", "Patrice", "Patricia", "Paul", "Philippe", "Pierre", "Rachel",
    "Raymond", "Remy", "Renaud", "Rene", "Richard", "Robert", "Roger", "Roland", "Sebastien", "Simone",
    "Sophie", "Stephane", "Suzanne", "Sylvain", "Sylvie", "Therese", "Thierry", "Thomas", "Valentine", "Valerie",
    "Vincent", "Virginie", "Xavier", "Yves", "Yvette", "Elton",

import random

def gerar_usuario_senha(num_usuarios=5000):
    usuarios_senhas = []

    for _ in range(num_usuarios):
        numero = random.randint(0, 99)
        nome = random.choice(nomes)  # Escolhe um nome aleatório da lista
        usuario = f"{nome}{numero:02d}"  # Cria o nome de usuário com o número
        senha1 = f"{numero:02d}{nome.capitalize()}"  # Cria a primeira senha formatada
        senha2 = f"{nome}{numero:02d}"  # Outra senha formatada
        senha3 = "102030"  # Senha fixa
        senha4 = "10203040"  # Senha fixa
        senha5 = "112233"  # Senha fixa
        senha6 = f"{nome.lower()}{numero:02d}"  # Senha formatada em minúsculas
        senha7 = f"{nome}123"  # Nova senha: nome seguido de 123
        senha8 = "123456789"  # Senha fixa
        senha9 = f"{numero:02d}{nome.lower()}"  # Senha NUM.NOM formatada em minúsculas
        # Adicionando opções de senha com os anos 2022, 2023 e 2024
        senha10 = f"{nome}2022"
        senha11 = f"{nome}2023"
        senha12 = f"{nome}2024"
        senha13 = f"{nome.lower()}"  # Cria a primeira senha formatada

        usuarios_senhas.extend([
            f"{usuario}:{senha1}",
            f"{usuario}:{senha2}",
            f"{usuario}:{senha3}",
            f"{usuario}:{senha4}",
            f"{usuario}:{senha5}",
            f"{usuario}:{senha6}",
            f"{usuario}:{senha7}",
            f"{usuario}:{senha8}",
            f"{usuario}:{senha9}",
            f"{usuario}:{senha10}",
            f"{usuario}:{senha11}",
            f"{usuario}:{senha12}",
            f"{usuario}:{senha13}",

        ])

    return usuarios_senhas

# Gerar 100000 usuários e senhas e salvar em um arquivo de texto no Google Drive
caminho_arquivo = '/content/drive/MyDrive/_Paineis/combo/usuarios_senhas.txt'
with open(caminho_arquivo, 'w') as file:
    # Gerar usuários e senhas
    usuarios_senhas = gerar_usuario_senha(50000)  # Gera os primeiros 2000
    file.write('\n'.join(usuarios_senhas) + '\n')

    usuarios_senhas = gerar_usuario_senha(50000)  # Gera os próximos 2000
    file.write('\n'.join(usuarios_senhas) + '\n')

print(f"Arquivo salvo em {caminho_arquivo}")

# %%
from google.colab import drive
drive.mount('/content/drive')
import random

# Lista expandida de nomes brasileiros
nomes = [
    "Joao", "Maria", "Pedro", "Ana", "Lucas", "Carla", "Rafael", "Fernanda", "Gabriel", "Juliana", "Bruno", "Larissa", "Felipe", "Camila", "Thiago", "Patricia", "Gustavo", "Renata", "Rodrigo", "Aline", "Daniel", "Beatriz", "Vinicius", "Mariana", "Leonardo", "Isabela", "Ricardo", "Tatiana", "Eduardo", "Vanessa", "Marcelo", "Leticia", "Andre", "Carolina", "Diego", "Natalia", "Fernando", "Bianca", "Alexandre", "Gabriela", "Rogerio", "Paula", "Murilo", "Sabrina", "Fabio", "Elaine", "Paulo", "Marcos", "Luisa", "Amanda", "Arthur", "Renato", "Raquel", "Carlos", "Bruna", "Alessandra", "Adriana", "Claudia", "Matheus", "Marta", "Julio", "Roberto", "Rita", "Edson", "Luciana", "Debora", "Gilberto", "Silvana", "Nelson", "Cecilia", "Tadeu", "Marlene", "Sonia", "Cassio", "Angela", "Josue", "Heloisa", "Paloma", "Ruan", "Vitor", "Lucio", "Mirela", "Flavio", "Simone", "Elias", "Katia", "Francisco", "Lorena", "Mario", "Otavio", "Evelyn", "Tiago", "Selma", "Vera", "Lucia", "Tulio", "Erica", "Saulo", "Cristina", "Wesley", "Thalita", "Josias", "Fabia", "Alfredo", "Manoela", "Cristiano", "Marcela", "Guilherme", "Roberta", "Marina", "Celso", "Stella", "Zeca", "Tatiane", "Leo", "Flora", "Marli", "Ronaldo", "Iraci", "Esther", "Jonathan", "Yuri", "Sara", "Wagner", "Hugo", "Jessica", "Fatima", "Douglas", "Ivone", "Valter", "Eder", "Leila", "Alvaro", "Nabia", "Raimundo", "Betina", "Eugenio", "Melissa", "Elen", "Mauricio", "Fabiana", "Otilia", "Emanuel", "Genilda", "Tomas", "Odete", "Newton", "Rabis", "Jorge", "Michele", "Caue", "Monica", "Tania", "Erick", "Jonas", "Clarissa", "Frederico", "Geni", "Claudio", "Luana", "Humberto", "Pietro", "Janaina", "Fausto", "Sergio", "Georgia", "Hilda", "Norma", "Isis", "Samuel", "Jairo", "Dandara", "Silvio", "Davi", "Dino", "Iris", "Vicente", "Ermelinda", "Arlindo", "Plinio", "Cida", "Alberto", "Norberto", "Albertina", "Marinalva", "Mara", "Evandro", "Iara", "Reinaldo", "Julio", "Regina", "Alice", "Emerson", "Lidiane", "Anderson", "Cibele", "Robson", "Naiane", "David", "Cassia", "Jefferson", "Sheila", "Rubens", "Maraisa", "Raimunda", "Eliete", "Lidia", "Karina", "Joana", "Emilia", "Alex", "Isabel", "Silvia", "Sandra", "Adriano", "Neusa", "Leandro", "Glaucia", "Osvaldo", "Olivia", "Igor", "Teresa", "Washington", "Edna", "Afonso", "Miriam", "Marilda", "Odair", "Estela", "Iracema", "Luiz", "Rosana", "Amadeu", "Eliane", "Heitor", "Edmilson", "Wallace", "Luiza", "Jose", "Valdir", "Magali", "Raul", "Valeria", "Elisabete", "Miguel", "Lazaro",

# [continuar a lista com mais nomes, usar a mesma formatação acimanomes]
]

# Função para gerar combinações de usuários e senhas
def gerar_usuario_senha(num_usuarios=25000):
    usuarios_senhas = []
    for nome in nomes:
        for numero in range(100):
            # Ambos, usuário e senha, terão o mesmo formato
            usuario_e_senha = f"{nome}{numero:02d}"
            usuarios_senhas.append(f"{usuario_e_senha}:{usuario_e_senha}")
    return usuarios_senhas

def gerar_usuario_senha():
    numero = random.randint(0, 99)
    nome = random.choice(nomes)
    usuario1 = f"{nome}{numero:02d}"
    senha1 = f"{nome.lower()}{numero:02d}"
    usuario2 = f"{nome.lower()}{numero:02d}"
    senha2 = f"{nome}{numero:02d}"
    return [f"{usuario1}:{senha1}", f"{usuario2}:{senha2}"]

# Gerar 50000 usuários e senhas e salvar em um arquivo de texto no Google Drive
caminho_arquivo = '/content/drive/MyDrive/_Paineis/combo/usuarios_senhas.txt'
with open(caminho_arquivo, 'w') as file:
    for _ in range(50000):
        for usuario_senha in gerar_usuario_senha():
            file.write(usuario_senha + '\n')

print(f"Arquivo salvo em {caminho_arquivo}")
